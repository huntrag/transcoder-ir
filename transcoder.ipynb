# %% [markdown]
# <a href="https://colab.research.google.com/github/huntrag/transcoder-ir/blob/main/transcoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The below code restarts kernal. So make sure you wait till it executes and then run it once again to see the message - "Everything looks OK!". Please use the T4 GPU as processor if haven't selected it yet.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# %% [markdown]
# This is will download the remote code from github which the contains the code for transpiling code. It will also download our cpp to rust model.

# %%
import os
# !git clone --single-branch --branch main https://github.com/facebookresearch/CodeGen.git
# !wget https://dl.fbaipublicfiles.com/transcoder/pre_trained_models/IR_project/IR_cpp_rust.pth

# %% [markdown]
# Renaming the requirements.txt in the code folder as it is not consistent with the installation script provided by the Codegen

# %%
os.chdir("CodeGen")

# !mv ci_requirements.txt requirements-notorch.txt

# %% [markdown]
# This will install all program dependencies through the script provided by Codegen. This might take around 12-15 minutes.

# %%
# !bash ./install_env.sh > file.txt

# %% [markdown]
# Trial for testing out one of the given codes in repository. Make sure you enter paths to files properly.

# %%
# !python -m codegen_sources.model.translate --src_lang cpp --tgt_lang rust --model_path ../IR_cpp_rust.pth --beam_size 1 < /content/CodeGen/data/transcoder_evaluation_gfg/cpp/ADD_1_TO_A_GIVEN_NUMBER.cpp
# Out:
# adding to path /content/CodeGen
# No efficient attention.
# Using /root/data/CodeGen/code_evaluation/tmp_tests_folder for temporary files.
# adding to path /content/CodeGen
# WARNING - 11/26/23 15:00:38 - 0:00:06 - Building cpp parser into /content/CodeGen/tree-sitter/cpp.so
# INFO - 11/26/23 15:00:38 - 0:00:06 - creating /tmp/tmp6_98f_ygtree_sitter_language/content
# INFO - 11/26/23 15:00:38 - 0:00:06 - creating /tmp/tmp6_98f_ygtree_sitter_language/content/CodeGen
# INFO - 11/26/23 15:00:38 - 0:00:06 - creating /tmp/tmp6_98f_ygtree_sitter_language/content/CodeGen/tree-sitter
# INFO - 11/26/23 15:00:38 - 0:00:06 - creating /tmp/tmp6_98f_ygtree_sitter_language/content/CodeGen/tree-sitter/tree-sitter-cpp
# INFO - 11/26/23 15:00:38 - 0:00:06 - creating /tmp/tmp6_98f_ygtree_sitter_language/content/CodeGen/tree-sitter/tree-sitter-cpp/src
# ...

# %%
# !mkdir ../output
# !mkdir ../output/cpp
# !mkdir ../output/rust

# %% [markdown]
# The script will translate all the cpp code in CodeGen/data/transcoder_evaluation_gfg/cpp. You can change the folder path as you wish

# %%
# !mv ../work.py codegen_sources/model/
# !bash ../script.sh > out.txt

# %% [markdown]
# The above code will do 350 codes in 2 hours.

# %%
# !zip -r /content/outputs.zip /content/output

# %% [markdown]
# ![Screenshot 2023-11-26 231352.png](data:image/png;base64,...)

# %% [markdown]
# Above is example of translation of following cpp code

# %% [markdown]
# ![Screenshot 2023-11-26 231420.png](data:image/png;base64,...)
